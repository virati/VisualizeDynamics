# %% [markdown]
# # Hopf-based Compute Network for Emotion Modeling
#
# ## Overview
#
# The goal of this notebook is to outline the development of a Hopf-dynamical compute network for emotion modeling.
#
#
# ## Introduction
#
# For the purposes here, we will pose *definitions* of emotion and mood. In the mathematical spirit, these definitions will then be followed through with each stage being rationally explained. If, in the end, the "logical consequences" of the axioms and logical steps contradicts any of the premises or catastrophically fails in the context of data (maybe defined as: no number of countable improvements can fix and greatly reduce divergence error) then the premises can be rejected.
#
# ### Hopf dynamics
#
# ### Emotion and Mood
# Current definitions of emotion and mood are X, Y in the science community. Clinically, mood disorders and other psychiatric disturbances consider emotion and mood Y,Z.
#
# Here, emotion will be considered the state, while mood will be considered a function of that state's dynamics. In this context, mood disorders are disorders of emotional/affective dynamics. This enables linear language (nullspaces, spans, rank, etc.) as well as non-linear language (bifurcations, stable manifolds, limit cycles, etc.)
#
# ## Basic Hopf bifurcation
#
# Let's import what we need

# %%
# %reset
import numpy as np
import hopf_element as hel
import matplotlib.pyplot as plt
fig_size = [0,0]
fig_size[0] = 12
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# Let's setup and display a quick example of a "normal form" hopf bifurcation
#
# Here, our state is an element of a two dimensional vector space
#
# $X = \{X,Y}$

# %%
mu = 1
simpleNet = hel.HopfNet(center_freq=2)
simpleNet.current_state = [-1.4,0]
simpleNet.plot_flow(mu=mu)
plt.show()
